# %% [markdown]
# ## 1. Libraries

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# ## 2. Load the CSV with semicolon separator

# %%
# CSV file path

#CSV_PATH = r'C:\Users\HP\Downloads\INFO\mobilenet.csv' 
#CSV_PATH = r'C:\Users\HP\Downloads\INFO\resnet50.csv' 
#CSV_PATH = r'C:\Users\HP\Downloads\INFO\xception.csv'  

# Load the CSV with semicolon separator
df = pd.read_csv(CSV_PATH, sep=';')
print(df.head())
# Out:
#    Epoch  Accuracy    Loss  Val_Accuracy  Val_Loss
# 0      1    0.7450  0.6981        0.9143    0.3583
# 1      2    0.8984  0.3545        0.9429    0.2051
# 2      3    0.9148  0.2622        0.9476    0.1645
# 3      4    0.9159  0.2322        0.9524    0.1449
# 4      5    0.9360  0.1950        0.9476    0.1342

# %%
print(df.columns)
# Out:
# Index(['Epoch', 'Accuracy', 'Loss', 'Val_Accuracy', 'Val_Loss'], dtype='object')

# %% [markdown]
# ## 3. Graph training and validation accuracy

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(4, 8))

# Graph Training Accuracy
plt.plot(df['Epoch'], df['Accuracy'], label='Training Accuracy', color='blue')

# Plot Validation Accuracy
plt.plot(df['Epoch'], df['Val_Accuracy'], label='Validation Accuracy', color='orange')

plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(False)
plt.show()

# %% [markdown]
# ## 4. Graph training and validation loss

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(4, 8))

# Graph Training Loss
plt.plot(df['Epoch'], df['Loss'], label='Training Loss', color='blue')

# Graph Validation Loss
plt.plot(df['Epoch'], df['Val_Loss'], label='Validation Loss', color='orange')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.ylim(0, max(df['Loss'].max(), df['Val_Loss'].max()) * 1.1)  
plt.grid(False)
plt.show()
